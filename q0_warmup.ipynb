# %% [markdown]
# # Task 0: Fashion MNIST classification in Pytorch (10 points)
#
# The goal of this task is to get you familiar with [Pytorch](https://pytorch.org/), teach you to debug your models, and give you a general understanding of deep learning and computer vision work-flows.
#
# [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) is a dataset of [Zalando’s](https://jobs.zalando.com/tech/) article images — consisting of 70,000 grayscale images in 10
# categories. Each example is a 28x28 grayscale image, associated with a label from 10 classes. ‘Fashion-
# MNIST’ is intended to serve as a direct **drop-in replacement** for the original [MNIST](http://yann.lecun.com/exdb/mnist/) dataset — often
# used as the “Hello, World” of machine learning programs for computer vision. It shares the same image
# size and structure of training and testing splits. We will use 60,000 images to train the network and
# 10,000 images to evaluate how accurately the network learned to classify images.

# %%
# installation directions can be found on pytorch's webpage
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
# %matplotlib inline

# import our network module from simple_cnn.py
from simple_cnn import SimpleCNN              # be sure to modify or you may have to restart kernel!
from importlib import reload
import simple_cnn

# %% [markdown]
# Usually you'll parse arguments using `argparse` (or similar library) but we can simply use a stand-in object for ipython notebooks. Furthermore, PyTorch can do computations on NVidia `GPU`s or on normal `CPU`s. You can configure the setting using the `device` variable.

# %%
class ARGS(object):
    # input batch size for training 
    batch_size = 64
    # input batch size for testing
    test_batch_size=1000
    # number of epochs to train for
    epochs = 14
    # learning rate
    lr = 1.0
    
    # Learning rate step gamma
    gamma = 0.7
    # how many batches to wait before logging training status
    log_every = 100
    # how many batches to wait before evaluating model
    val_every = 100
    # set true if using GPU during training
    use_cuda = True

args = ARGS()
device = torch.device("cuda" if args.use_cuda else "cpu")

# %% [markdown]
# We define some basic testing and training code. The testing code prints out the average test loss and the training code (`main`) plots train/test losses and returns the final model.

# %%
def test(model, device, test_loader):
    """Evaluate model on test dataset."""
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    return test_loss, correct / len(test_loader.dataset)

def main():
    # 1. load dataset and build dataloader
    train_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST('../data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.test_batch_size, shuffle=True)

    # 2. define the model, and optimizer.
    model = SimpleCNN().to(device)
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=args.gamma)
    cnt = 0
    train_log = {'iter': [], 'loss': [], 'accuracy': []}
    test_log = {'iter': [], 'loss': [], 'accuracy': []}
    for epoch in range(args.epochs):
        for batch_idx, (data, target) in enumerate(train_loader):
            # Get a batch of data
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            # Forward pass
            output = model(data)
            # Calculate the loss
            loss = F.cross_entropy(output, target)
            # Calculate gradient w.r.t the loss
            loss.backward()
            # Optimizer takes one step
            optimizer.step()
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            
            # Log info
            if cnt % args.log_every == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, cnt, len(train_loader.dataset),
                           100. * batch_idx / len(train_loader), loss.item()))
                train_log['iter'].append(cnt)
                train_log['loss'].append(loss)
                # TODO: calculate your train accuracy!
                train_acc = pred.eq(target.view_as(pred)).sum().item() / args.batch_size
                train_log['accuracy'].append(train_acc)
            # Validation iteration
            if cnt % args.val_every == 0:
                test_loss, test_acc = test(model, device, test_loader)
                test_log['iter'].append(cnt)
                test_log['loss'].append(test_loss)
                test_log['accuracy'].append(test_acc)
                model.train()
            cnt += 1
        scheduler.step()
    fig = plt.figure()
    plt.plot(train_log['iter'], train_log['loss'], 'r', label='Training')
    plt.plot(test_log['iter'], test_log['loss'], 'b', label='Testing')
    plt.title('Loss')
    plt.legend()
    fig = plt.figure()
    plt.plot(train_log['iter'], train_log['accuracy'], 'r', label='Training')
    plt.plot(test_log['iter'], test_log['accuracy'], 'b', label='Testing')
    plt.title('Accuracy')
    plt.legend()
    plt.show()
    return model

# %% [markdown]
# ## 0.1 Bug Fix and Hyper-parameter search. (2pts)
#
# Simply running `main` will result in a `RuntimeError`! Check out `simple_cnn.py` and see if you can fix the bug. You may have to restart your ipython kernel for changes to reflect in the notebook. After that's done, be sure to fill in the TODOs in `main`.
#
#
# Once you fix the bugs, you should be able to get a reasonable accuracy within 100 iterations just by tuning some hyper-parameter. Include the train/test plots of your best hyperparamter setting and comment on why you think these settings worked best. (you can complete this task on CPU)
#
# **YOUR ANSWER HERE**
#
# The best accuracy I got with tuned hyperparameters is 84%. I noticed that the learning rate was super high, so I reduced it from 1.0 to 1e-3 which increased accuracy from ~79 to ~84. The model was also definitely training way more than it needed to so I stopped it after 5 epochs.

# %%
#### FEEL FREE TO MODIFY args VARIABLE HERE OR ABOVE ####
# args.gamma = float('inf')
args.lr = 1e-3
args.epochs = 5
args.gamma = 0.1
reload(simple_cnn)
from simple_cnn import SimpleCNN
# DON'T CHANGE
# prints out arguments and runs main

for attr in dir(args):
    if '__' not in attr and attr !='use_cuda':
        print('args.{} = {}'.format(attr, getattr(args, attr)))
print('\n\n')
model = main()
# Out:
# args.batch_size = 64
# args.epochs = 5
# args.gamma = 0.1
# args.log_every = 100
# args.lr = 0.001
# args.test_batch_size = 1000
# args.val_every = 100
#
#
#
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.312484
#
# Test set: Average loss: 2.2431, Accuracy: 2395/10000 (24%)
#
# Train Epoch: 0 [100/60000 (11%)]	Loss: 0.903520
#
# Test set: Average loss: 0.5565, Accuracy: 7977/10000 (80%)
#
# Train Epoch: 0 [200/60000 (21%)]	Loss: 0.450690
#
# Test set: Average loss: 0.5074, Accuracy: 8123/10000 (81%)
#
# Train Epoch: 0 [300/60000 (32%)]	Loss: 0.260696
#
# Test set: Average loss: 0.4499, Accuracy: 8334/10000 (83%)
#
# Train Epoch: 0 [400/60000 (43%)]	Loss: 0.287939
#
# Test set: Average loss: 0.4253, Accuracy: 8466/10000 (85%)
#
# Train Epoch: 0 [500/60000 (53%)]	Loss: 0.331026
#
# Test set: Average loss: 0.4200, Accuracy: 8440/10000 (84%)
#
# Train Epoch: 0 [600/60000 (64%)]	Loss: 0.296970
#
# Test set: Average loss: 0.3965, Accuracy: 8559/10000 (86%)
#
# Train Epoch: 0 [700/60000 (75%)]	Loss: 0.479419
#
# Test set: Average loss: 0.3820, Accuracy: 8613/10000 (86%)
#
# Train Epoch: 0 [800/60000 (85%)]	Loss: 0.324480
#
# Test set: Average loss: 0.3626, Accuracy: 8716/10000 (87%)
#
# Train Epoch: 0 [900/60000 (96%)]	Loss: 0.162743
#
# Test set: Average loss: 0.3560, Accuracy: 8710/10000 (87%)
#
# Train Epoch: 1 [1000/60000 (7%)]	Loss: 0.213626
#
# Test set: Average loss: 0.3274, Accuracy: 8813/10000 (88%)
#
# Train Epoch: 1 [1100/60000 (17%)]	Loss: 0.288765
#
# Test set: Average loss: 0.3207, Accuracy: 8820/10000 (88%)
#
# Train Epoch: 1 [1200/60000 (28%)]	Loss: 0.267903
#
# Test set: Average loss: 0.3152, Accuracy: 8826/10000 (88%)
#
# Train Epoch: 1 [1300/60000 (39%)]	Loss: 0.260287
#
# Test set: Average loss: 0.3127, Accuracy: 8864/10000 (89%)
#
# Train Epoch: 1 [1400/60000 (49%)]	Loss: 0.339047
#
# Test set: Average loss: 0.3076, Accuracy: 8883/10000 (89%)
#
# Train Epoch: 1 [1500/60000 (60%)]	Loss: 0.221488
#
# Test set: Average loss: 0.3094, Accuracy: 8878/10000 (89%)
#
# Train Epoch: 1 [1600/60000 (71%)]	Loss: 0.237943
#
# Test set: Average loss: 0.3075, Accuracy: 8879/10000 (89%)
#
# Train Epoch: 1 [1700/60000 (81%)]	Loss: 0.266006
#
# Test set: Average loss: 0.3071, Accuracy: 8886/10000 (89%)
#
# Train Epoch: 1 [1800/60000 (92%)]	Loss: 0.275911
#
# Test set: Average loss: 0.3027, Accuracy: 8895/10000 (89%)
#
# Train Epoch: 2 [1900/60000 (3%)]	Loss: 0.200963
#
# Test set: Average loss: 0.3012, Accuracy: 8907/10000 (89%)
#
# Train Epoch: 2 [2000/60000 (13%)]	Loss: 0.215666
#
# Test set: Average loss: 0.2997, Accuracy: 8909/10000 (89%)
#
# Train Epoch: 2 [2100/60000 (24%)]	Loss: 0.371218
#
# Test set: Average loss: 0.2996, Accuracy: 8907/10000 (89%)
#
# Train Epoch: 2 [2200/60000 (35%)]	Loss: 0.222917
#
# Test set: Average loss: 0.2990, Accuracy: 8906/10000 (89%)
#
# Train Epoch: 2 [2300/60000 (45%)]	Loss: 0.149638
#
# Test set: Average loss: 0.2987, Accuracy: 8906/10000 (89%)
#
# Train Epoch: 2 [2400/60000 (56%)]	Loss: 0.264282
#
# Test set: Average loss: 0.2983, Accuracy: 8906/10000 (89%)
#
# Train Epoch: 2 [2500/60000 (67%)]	Loss: 0.247623
#
# Test set: Average loss: 0.2982, Accuracy: 8909/10000 (89%)
#
# Train Epoch: 2 [2600/60000 (77%)]	Loss: 0.179419
#
# Test set: Average loss: 0.2975, Accuracy: 8928/10000 (89%)
#
# Train Epoch: 2 [2700/60000 (88%)]	Loss: 0.357166
#
# Test set: Average loss: 0.2977, Accuracy: 8918/10000 (89%)
#
# Train Epoch: 2 [2800/60000 (99%)]	Loss: 0.262933
#
# Test set: Average loss: 0.2976, Accuracy: 8901/10000 (89%)
#
# Train Epoch: 3 [2900/60000 (9%)]	Loss: 0.290387
#
# Test set: Average loss: 0.2973, Accuracy: 8913/10000 (89%)
#
# Train Epoch: 3 [3000/60000 (20%)]	Loss: 0.254417
#
# Test set: Average loss: 0.2974, Accuracy: 8913/10000 (89%)
#
# Train Epoch: 3 [3100/60000 (30%)]	Loss: 0.243682
#
# Test set: Average loss: 0.2973, Accuracy: 8911/10000 (89%)
#
# Train Epoch: 3 [3200/60000 (41%)]	Loss: 0.292405
#
# Test set: Average loss: 0.2973, Accuracy: 8914/10000 (89%)
#
# Train Epoch: 3 [3300/60000 (52%)]	Loss: 0.186677
#
# Test set: Average loss: 0.2972, Accuracy: 8913/10000 (89%)
#
# Train Epoch: 3 [3400/60000 (62%)]	Loss: 0.337647
#
# Test set: Average loss: 0.2972, Accuracy: 8916/10000 (89%)
#
# Train Epoch: 3 [3500/60000 (73%)]	Loss: 0.181238
#
# Test set: Average loss: 0.2971, Accuracy: 8920/10000 (89%)
#
# Train Epoch: 3 [3600/60000 (84%)]	Loss: 0.264948
#
# Test set: Average loss: 0.2970, Accuracy: 8919/10000 (89%)
#
# Train Epoch: 3 [3700/60000 (94%)]	Loss: 0.280360
#
# Test set: Average loss: 0.2970, Accuracy: 8922/10000 (89%)
#
# Train Epoch: 4 [3800/60000 (5%)]	Loss: 0.406641
#
# Test set: Average loss: 0.2970, Accuracy: 8920/10000 (89%)
#
# Train Epoch: 4 [3900/60000 (16%)]	Loss: 0.299356
#
# Test set: Average loss: 0.2970, Accuracy: 8921/10000 (89%)
#
# Train Epoch: 4 [4000/60000 (26%)]	Loss: 0.283008
#
# Test set: Average loss: 0.2970, Accuracy: 8921/10000 (89%)
#
# Train Epoch: 4 [4100/60000 (37%)]	Loss: 0.385570
#
# Test set: Average loss: 0.2970, Accuracy: 8920/10000 (89%)
#
# Train Epoch: 4 [4200/60000 (48%)]	Loss: 0.233755
#
# Test set: Average loss: 0.2970, Accuracy: 8920/10000 (89%)
#
# Train Epoch: 4 [4300/60000 (58%)]	Loss: 0.258007
#
# Test set: Average loss: 0.2970, Accuracy: 8920/10000 (89%)
#
# Train Epoch: 4 [4400/60000 (69%)]	Loss: 0.218863
#
# Test set: Average loss: 0.2970, Accuracy: 8920/10000 (89%)
#
# Train Epoch: 4 [4500/60000 (80%)]	Loss: 0.127287
#
# Test set: Average loss: 0.2970, Accuracy: 8920/10000 (89%)
#
# Train Epoch: 4 [4600/60000 (90%)]	Loss: 0.320199
#
# Test set: Average loss: 0.2970, Accuracy: 8920/10000 (89%)

# %% [markdown]
# ## Play with parameters.(3pt)
# How many trainable parameters does the trained model have?

# %%
def param_count(model):
    #print(list(model.parameters()))
    n = 0
    for param in model.parameters():
        shape = param.size()
        res = 1
        for dim in shape:
            res *= dim
        n += res
    return(n)
print('Model has {} params'.format(param_count(model)))
# Out:
# Model has 454922 params

# %% [markdown]
# ## Deep Linear Networks?!? (5pt)
# Until this point, there are no non-linearities in the SimpleCNN! (Your TAs were just as surprised as you are at the results.) Your next task is to modify the code to add non-linear activation layers, and train your model in full scale. Make sure to add non-linearities at **every** applicable layer.
#
# Compute the loss and accuracy curves on train and test sets after 5 epochs.

# %%
args.epochs = 5
reload(simple_cnn)
from simple_cnn import SimpleCNN
main()
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.311986
#
# Test set: Average loss: 2.2724, Accuracy: 1765/10000 (18%)
#
# Train Epoch: 0 [100/60000 (11%)]	Loss: 0.697245
#
# Test set: Average loss: 0.5817, Accuracy: 7924/10000 (79%)
#
# Train Epoch: 0 [200/60000 (21%)]	Loss: 0.446573
#
# Test set: Average loss: 0.5308, Accuracy: 8019/10000 (80%)
#
# Train Epoch: 0 [300/60000 (32%)]	Loss: 0.624897
#
# Test set: Average loss: 0.4618, Accuracy: 8358/10000 (84%)
#
# Train Epoch: 0 [400/60000 (43%)]	Loss: 0.322647
#
# Test set: Average loss: 0.4157, Accuracy: 8495/10000 (85%)
#
# Train Epoch: 0 [500/60000 (53%)]	Loss: 0.445121
#
# Test set: Average loss: 0.4442, Accuracy: 8360/10000 (84%)
#
# Train Epoch: 0 [600/60000 (64%)]	Loss: 0.443866
#
# Test set: Average loss: 0.4267, Accuracy: 8404/10000 (84%)
#
# Train Epoch: 0 [700/60000 (75%)]	Loss: 0.397609
#
# Test set: Average loss: 0.3651, Accuracy: 8683/10000 (87%)
#
# Train Epoch: 0 [800/60000 (85%)]	Loss: 0.255770
#
# Test set: Average loss: 0.3891, Accuracy: 8609/10000 (86%)
#
# Train Epoch: 0 [900/60000 (96%)]	Loss: 0.296307
#
# Test set: Average loss: 0.3578, Accuracy: 8691/10000 (87%)
#
# Train Epoch: 1 [1000/60000 (7%)]	Loss: 0.194236
#
# Test set: Average loss: 0.3246, Accuracy: 8825/10000 (88%)
#
# Train Epoch: 1 [1100/60000 (17%)]	Loss: 0.293211
#
# Test set: Average loss: 0.3174, Accuracy: 8844/10000 (88%)
#
# Train Epoch: 1 [1200/60000 (28%)]	Loss: 0.289429
#
# Test set: Average loss: 0.3136, Accuracy: 8845/10000 (88%)
#
# Train Epoch: 1 [1300/60000 (39%)]	Loss: 0.127335
#
# Test set: Average loss: 0.3106, Accuracy: 8868/10000 (89%)
#
# Train Epoch: 1 [1400/60000 (49%)]	Loss: 0.246154
#
# Test set: Average loss: 0.3096, Accuracy: 8878/10000 (89%)
#
# Train Epoch: 1 [1500/60000 (60%)]	Loss: 0.281575
#
# Test set: Average loss: 0.3083, Accuracy: 8865/10000 (89%)
#
# Train Epoch: 1 [1600/60000 (71%)]	Loss: 0.294735
#
# Test set: Average loss: 0.3064, Accuracy: 8870/10000 (89%)
#
# Train Epoch: 1 [1700/60000 (81%)]	Loss: 0.286229
#
# Test set: Average loss: 0.3070, Accuracy: 8883/10000 (89%)
#
# Train Epoch: 1 [1800/60000 (92%)]	Loss: 0.260881
#
# Test set: Average loss: 0.3034, Accuracy: 8890/10000 (89%)
#
# Train Epoch: 2 [1900/60000 (3%)]	Loss: 0.256224
#
# Test set: Average loss: 0.3039, Accuracy: 8892/10000 (89%)
#
# Train Epoch: 2 [2000/60000 (13%)]	Loss: 0.270119
#
# Test set: Average loss: 0.3013, Accuracy: 8901/10000 (89%)
#
# Train Epoch: 2 [2100/60000 (24%)]	Loss: 0.333566
#
# Test set: Average loss: 0.3005, Accuracy: 8910/10000 (89%)
#
# Train Epoch: 2 [2200/60000 (35%)]	Loss: 0.236964
#
# Test set: Average loss: 0.2998, Accuracy: 8918/10000 (89%)
#
# Train Epoch: 2 [2300/60000 (45%)]	Loss: 0.242509
#
# Test set: Average loss: 0.2998, Accuracy: 8898/10000 (89%)
#
# Train Epoch: 2 [2400/60000 (56%)]	Loss: 0.199586
#
# Test set: Average loss: 0.2991, Accuracy: 8918/10000 (89%)
#
# Train Epoch: 2 [2500/60000 (67%)]	Loss: 0.178485
#
# Test set: Average loss: 0.2989, Accuracy: 8908/10000 (89%)
#
# Train Epoch: 2 [2600/60000 (77%)]	Loss: 0.193281
#
# Test set: Average loss: 0.2986, Accuracy: 8899/10000 (89%)
#
# Train Epoch: 2 [2700/60000 (88%)]	Loss: 0.233340
#
# Test set: Average loss: 0.2983, Accuracy: 8916/10000 (89%)
#
# Train Epoch: 2 [2800/60000 (99%)]	Loss: 0.209046
#
# Test set: Average loss: 0.2978, Accuracy: 8912/10000 (89%)
#
# Train Epoch: 3 [2900/60000 (9%)]	Loss: 0.257895
#
# Test set: Average loss: 0.2979, Accuracy: 8908/10000 (89%)
#
# Train Epoch: 3 [3000/60000 (20%)]	Loss: 0.390827
#
# Test set: Average loss: 0.2977, Accuracy: 8909/10000 (89%)
#
# Train Epoch: 3 [3100/60000 (30%)]	Loss: 0.329950
#
# Test set: Average loss: 0.2977, Accuracy: 8914/10000 (89%)
#
# Train Epoch: 3 [3200/60000 (41%)]	Loss: 0.195984
#
# Test set: Average loss: 0.2976, Accuracy: 8913/10000 (89%)
#
# Train Epoch: 3 [3300/60000 (52%)]	Loss: 0.172654
#
# Test set: Average loss: 0.2976, Accuracy: 8915/10000 (89%)
#
# Train Epoch: 3 [3400/60000 (62%)]	Loss: 0.095213
#
# Test set: Average loss: 0.2976, Accuracy: 8913/10000 (89%)
#
# Train Epoch: 3 [3500/60000 (73%)]	Loss: 0.327329
#
# Test set: Average loss: 0.2976, Accuracy: 8905/10000 (89%)
#
# Train Epoch: 3 [3600/60000 (84%)]	Loss: 0.324875
#
# Test set: Average loss: 0.2975, Accuracy: 8916/10000 (89%)
#
# Train Epoch: 3 [3700/60000 (94%)]	Loss: 0.120883
#
# Test set: Average loss: 0.2975, Accuracy: 8916/10000 (89%)
#
# Train Epoch: 4 [3800/60000 (5%)]	Loss: 0.312332
#
# Test set: Average loss: 0.2975, Accuracy: 8917/10000 (89%)
#
# Train Epoch: 4 [3900/60000 (16%)]	Loss: 0.275570
#
# Test set: Average loss: 0.2975, Accuracy: 8918/10000 (89%)
#
# Train Epoch: 4 [4000/60000 (26%)]	Loss: 0.236512
#
# Test set: Average loss: 0.2975, Accuracy: 8918/10000 (89%)
#
# Train Epoch: 4 [4100/60000 (37%)]	Loss: 0.298589
#
# Test set: Average loss: 0.2975, Accuracy: 8916/10000 (89%)
#
# Train Epoch: 4 [4200/60000 (48%)]	Loss: 0.187761
#
# Test set: Average loss: 0.2975, Accuracy: 8916/10000 (89%)
#
# Train Epoch: 4 [4300/60000 (58%)]	Loss: 0.230286
#
# Test set: Average loss: 0.2975, Accuracy: 8918/10000 (89%)
#
# Train Epoch: 4 [4400/60000 (69%)]	Loss: 0.286657
#
# Test set: Average loss: 0.2975, Accuracy: 8917/10000 (89%)
#
# Train Epoch: 4 [4500/60000 (80%)]	Loss: 0.414135
#
# Test set: Average loss: 0.2975, Accuracy: 8916/10000 (89%)
#
# Train Epoch: 4 [4600/60000 (90%)]	Loss: 0.239827
#
# Test set: Average loss: 0.2975, Accuracy: 8916/10000 (89%)
# SimpleCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (nonlinear): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (pool2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc1): Sequential(
#     (0): Linear(in_features=3136, out_features=128, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# Where did you add your non-linearities?
#
# **YOUR ANSWER HERE**
#
# I applied my nonlinearities to the output of each convolutional layer in the feature extraction backbone.
#
# <br><br><br>
# Provide some insights on why the results was fairly good even without activation layers. (**2** pts)
#
# **YOUR ANSWER HERE**
#
# As mentioned in the homework prompt, the MNIST task is fairly simple, with relatively  low dimensional (for computer vision tasks) input and a small number of classes. Linear methods may be expressive enough for such a task
